# %%
# %run "/Workspace/Users/jayadheep356@gmail.com/DATABRICKS_ASSIGNMENT/src/rawdata_to_bronze/utils"

# %%
employee_path = "/Volumes/custom_catalog/db_assignment/source/raw_data/Employee-Q1.csv"
department_path = "/Volumes/custom_catalog/db_assignment/source/raw_data/Department-Q1.csv"
country_path = "/Volumes/custom_catalog/db_assignment/source/raw_data/Country-Q1.csv"

# Read source data
employee_df = read_csv_file(spark, employee_path)
department_df = read_csv_file(spark, department_path)
country_df = read_csv_file(spark, country_path)

# Write to DBFS Bronze Layer (as CSV)
write_df_to_csv(employee_df, "/Volumes/custom_catalog/db_assignment/source/bronze/employee.csv")
write_df_to_csv(department_df, "/Volumes/custom_catalog/db_assignment/source/bronze/department.csv")
write_df_to_csv(country_df, "/Volumes/custom_catalog/db_assignment/source/bronze/country.csv")

#To display the data
display(employee_df)
display(department_df)
display(country_df)
